# %%
%load_ext rpy2.ipython
%R X=c(1,4,5,7); sd(X); mean(X)
# Out:
# array([ 4.25])

# %%
import pandas as pd

# %%
temp_data = [1,2,3,4,5,6,7,8]
print(temp_data[2:4])
# Out:
# [3, 4]

# %%
%R library(car)
# Out:
# array(['car', 'tools', 'stats', 'graphics', 'grDevices', 'utils',
#        'datasets', 'methods', 'base'],
#       dtype='<U9')

# %%
%R car <- library(car)
# Out:
# array(['car', 'tools', 'stats', 'graphics', 'grDevices', 'utils',
#        'datasets', 'methods', 'base'],
#       dtype='<U9')

# %%
%R car
# Out:
# array(['car', 'tools', 'stats', 'graphics', 'grDevices', 'utils',
#        'datasets', 'methods', 'base'],
#       dtype='<U9')

# %%
%R class(car)
# Out:
# array(['character'],
#       dtype='<U9')

# %% [markdown]
# # Regression Test

# %% [markdown]
# ## Outliers

# %%
library(car)
fit <- lm(mpg~disp+hp+wt+drat, data=mtcars)
# Out:
# Warning message:
# "package 'car' was built under R version 3.3.2"

# %%
head(mtcars,3)
mtcars
# Out:
#               mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4     21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag 21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710    22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
#                     mpg  cyl disp  hp  drat wt    qsec  vs am gear carb
# Mazda RX4           21.0 6   160.0 110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag       21.0 6   160.0 110 3.90 2.875 17.02 0  1  4    4
# Datsun 710          22.8 4   108.0  93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive      21.4 6   258.0 110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout   18.7 8   360.0 175 3.15 3.440 17.02 0  0  3    2
# Valiant             18.1 6   225.0 105 2.76 3.460 20.22 1  0  3    1
# Duster 360          14.3 8   360.0 245 3.21 3.570 15.84 0  0  3    4
# Merc 240D           24.4 4   146.7  62 3.69 3.190 20.00 1  0  4    2
# Merc 230            22.8 4   140.8  95 3.92 3.150 22.90 1  0  4    2
# ...

# %%
outlierTest(fit)
qqPlot(fit, main="QQ Plot")
leveragePlots(fit)
# Out:
# No Studentized residuals with Bonferonni p < 0.05
# Largest |rstudent|:
#                rstudent unadjusted p-value Bonferonni p
# Toyota Corolla  2.51597            0.01838      0.58816
# Plot with title "QQ Plot"
# plot without title

# %%
# Influential Observations
# added variable plots 
avPlots(fit)
# Cook's D plot
# identify D values > 4/(n-k-1) 
cutoff <- 4/((nrow(mtcars)-length(fit$coefficients)-2)) 
plot(fit, which=4, cook.levels=cutoff)
# Influence Plot 
influencePlot(fit,	id.method="identify", main="Influence Plot", sub="Circle size is proportial to Cook's Distance" )
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “Influence Plot”

# %%
# Normality of Residuals
# qq plot for studentized resid
qqPlot(fit, main="QQ Plot")
# distribution of studentized residuals
library(MASS)
sresid <- studres(fit) 
hist(sresid, freq=FALSE, 
   main="Distribution of Studentized Residuals")
xfit<-seq(min(sresid),max(sresid),length=40) 
yfit<-dnorm(xfit) 
lines(xfit, yfit)
# Out:
# Plot with title “QQ Plot”
# Plot with title “Distribution of Studentized Residuals”

# %%
# Evaluate homoscedasticity
# non-constant error variance test
ncvTest(fit)
# plot studentized residuals vs. fitted values 
spreadLevelPlot(fit)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 1.429672    Df = 1     p = 0.231818
# Suggested power transformation:  0.6616338
# Plot with title “Spread-Level Plot for
#  fit”

# %%
# Evaluate Collinearity
vif(fit) # variance inflation factors 
sqrt(vif(fit)) > 2 # problem?
# Out:
#     disp       hp       wt     drat
# 8.209402 2.894373 5.096601 2.279547
#  disp    hp    wt  drat
#  TRUE FALSE  TRUE FALSE

# %%
# Evaluate Nonlinearity
# component + residual plot 
crPlots(fit)
# Ceres plots 
ceresPlots(fit)
# Out:
# plot without title
# Plot with title “”

# %%
# Test for Autocorrelated Errors
durbinWatsonTest(fit)
# Out:
#  lag Autocorrelation D-W Statistic p-value
#    1        0.100862      1.735915   0.292
#  Alternative hypothesis: rho != 0

# %%
# Global test of model assumptions
#library(gvlma)
#gvmodel <- gvlma(fit) 
#summary(gvmodel)

# %% [markdown]
# ## R Regression Example with Harvard

# %%
getwd()
# Out:
# [1] "C:/Users/huodi/Documents/python"

# %%
library(foreign)

# %%
#states.data <- read.dta("/Users/Lydia/GraphLab/0534396542_3989/states.dta", convert.dates = TRUE, convert.factors = TRUE,
#         missing.type = FALSE,
#         convert.underscore = FALSE, warn.missing.labels = TRUE)
states.data <- readRDS("dataSets/states.rds")

# %%
class(states.data)
# Out:
# [1] "data.frame"

# %%
states.info <- data.frame(attributes(states.data)[c("names", "var.labels")])

# %%
tail(states.info, 8)
# Out:
#    names   var.labels
# 14 csat    Mean composite SAT score
# 15 vsat    Mean verbal SAT score
# 16 msat    Mean math SAT score
# 17 percent % HS graduates taking SAT
# 18 expense Per pupil expenditures prim&sec
# 19 income  Median household income, $1,000
# 20 high    % adults HS diploma
# 21 college % adults college degree

# %%
sts.ex.sat <- subset(states.data,select=c("expense","csat"))
#sts.ex.sat <- subset(states.data,select=c("expense","csat","vsat","msat"))

# %%
summary(sts.ex.sat)
# Out:
#     expense          csat
#  Min.   :2960   Min.   : 832.0
#  1st Qu.:4352   1st Qu.: 888.0
#  Median :5000   Median : 926.0
#  Mean   :5236   Mean   : 944.1
#  3rd Qu.:5794   3rd Qu.: 997.0
#  Max.   :9259   Max.   :1093.0

# %%
cor(sts.ex.sat)
# Out:
#         expense    csat
# expense  1.0000000 -0.4662978
# csat    -0.4662978  1.0000000

# %%
plot(sts.ex.sat)
# Out:
# plot without title

# %%
sat.mod <- lm(csat ~ expense, # regression formula
              data=states.data) # data set

# %%
summary(sat.mod)
# Out:
# Call:
# lm(formula = csat ~ expense, data = states.data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -131.811  -38.085    5.607   37.852  136.495
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.061e+03  3.270e+01   32.44  < 2e-16 ***
# expense     -2.228e-02  6.037e-03   -3.69 0.000563 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 59.81 on 49 degrees of freedom
# Multiple R-squared:  0.2174,	Adjusted R-squared:  0.2015
# F-statistic: 13.61 on 1 and 49 DF,  p-value: 0.0005631

# %%
summary(lm(csat ~ expense + percent, data = states.data))
# Out:
# Call:
# lm(formula = csat ~ expense + percent, data = states.data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -62.921 -24.318   1.741  15.502  75.623
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 989.807403  18.395770  53.806  < 2e-16 ***
# expense       0.008604   0.004204   2.046   0.0462 *
# percent      -2.537700   0.224912 -11.283 4.21e-15 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 31.62 on 48 degrees of freedom
# Multiple R-squared:  0.7857,	Adjusted R-squared:  0.7768
# F-statistic: 88.01 on 2 and 48 DF,  p-value: < 2.2e-16

# %%
names(sat.mod)
coefficients(sat.mod)
# Out:
#  [1] "coefficients"  "residuals"     "effects"       "rank"
#  [5] "fitted.values" "assign"        "qr"            "df.residual"
#  [9] "xlevels"       "call"          "terms"         "model"
#   (Intercept)       expense
# 1060.73244395   -0.02227565

# %%
class(sat.mod)
# Out:
# [1] "lm"

# %%
methods(class = class(sat.mod))[1:9]
# Out:
# [1] "add1.lm"       "alias.lm"      "anova.lm"      "Anova.lm"
# [5] "avPlot.lm"     "Boot.lm"       "bootCase.lm"   "boxCox.lm"
# [9] "case.names.lm"

# %%
confint(sat.mod)
# Out:
#             2.5 %        97.5 %
# (Intercept) 995.01753164 1126.44735626
# expense      -0.03440768   -0.01014361

# %%
  # fit another model, adding house and senate as predictors
  sat.voting.mod <-  lm(csat ~ expense + house + senate,
                        data = na.omit(states.data))
  sat.mod <- update(sat.mod, data=na.omit(states.data))
  # compare using the anova() function
  anova(sat.mod, sat.voting.mod)
  coef(summary(sat.voting.mod))
# Out:
#   Res.Df RSS      Df Sum of Sq F        Pr(>F)
# 1 46     169049.9 NA       NA        NA         NA
# 2 44     149284.4  2 19765.51  2.912838 0.06486174
#             Estimate      Std. Error   t value    Pr(>|t|)
# (Intercept) 1082.93438041 38.633812740 28.0307405 1.067795e-29
# expense       -0.01870832  0.009691494 -1.9303852 6.001998e-02
# house         -1.44243754  0.600478382 -2.4021473 2.058666e-02
# senate         0.49817861  0.513561356  0.9700469 3.373256e-01

# %%
x <- rnorm(15)
y <- x + rnorm(15)
predict(lm(y ~ x))
new <- data.frame(x = seq(-3, 3, 0.5))
predict(lm(y ~ x), new, interval = c("none", "confidence", "prediction"))
# Out:
#          1          2          3          4          5          6          7
# -1.3879547  1.3019095 -1.4647381  1.7157532 -0.1152459 -0.6554897  0.7460571
#          8          9         10         11         12         13         14
#  2.1273957  1.2507906  0.9369893 -0.4971379 -0.9743377  0.4015319 -0.9203972
#         15
# -0.1419907
#          1          2          3          4          5          6          7
# -3.7629859 -3.0552175 -2.3474492 -1.6396809 -0.9319125 -0.2241442  0.4836241
#          8          9         10         11         12         13
#  1.1913925  1.8991608  2.6069291  3.3146975  4.0224658  4.7302341

# %% [markdown]
# ## Model Validation & Assumption Test

# %% [markdown]
# ### Extrem value test

# %%
#When trying to identify outliers, one problem that can arise is when there is a potential outlier that influences the regression model to such an extent 
#that the estimated regression function is "pulled" towards the potential outlier, so that it isn't flagged as an outlier 
#using the standardized residual criterion.
outlierTest(sat.mod)
qqPlot(sat.mod , main="QQ Plot")
leveragePlots(sat.mod)
# Out:
# No Studentized residuals with Bonferonni p < 0.05
# Largest |rstudent|:
#    rstudent unadjusted p-value Bonferonni p
# 16 2.420147           0.019349       0.9868
# Plot with title "QQ Plot"
# plot without title

# %%
# added variable plots 
avPlots(sat.mod)
# Cook's D plot
# identify D values > 4/(n-k-1) 
cutoff <- 4/((nrow(sts.ex.sat)-length(sat.mod$coefficients)-2)) 
plot(sat.mod, which=4, cook.levels=cutoff)
# Influence Plot 
influencePlot(sat.mod,	id.method="identify", main="Influence Plot", sub="Circle size is proportial to Cook's Distance" )
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title "Influence Plot"

# %% [markdown]
# ### Normality of Residuals

# %%
# Normality of Residuals
# qq plot for studentized resid
qqPlot(sat.mod , main="QQ Plot")
# distribution of studentized residuals
library(MASS)
sresid <- studres(sat.mod ) 
hist(sresid, freq=FALSE, 
   main="Distribution of Studentized Residuals")
xfit<-seq(min(sresid),max(sresid),length=40) 
yfit<-dnorm(xfit) 
lines(xfit, yfit)

shapiro.test(residuals(sat.mod))
qqnorm(residuals(sat.mod))

#hist(residuals(sat.mod))
# Out:
# Plot with title "QQ Plot"
# 	Shapiro-Wilk normality test
#
# data:  residuals(sat.mod)
# W = 0.99144, p-value = 0.9719
# Plot with title "Distribution of Studentized Residuals"
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# ### Evaluate homoscedasticity

# %%
# non-constant error variance test
ncvTest(sat.mod)
# plot studentized residuals vs. fitted values 
spreadLevelPlot(sat.mod)
# Out:
# Non-constant Variance Score Test
# Variance formula: ~ fitted.values
# Chisquare = 2.138966    Df = 1     p = 0.1435987
# Suggested power transformation:  -5.699595
# Plot with title "Spread-Level Plot for
#  sat.mod"

# %% [markdown]
# ### Errors are independent and the relationships are linear

# %% [markdown]
# #### Independent Test with Chi-squared Pearson's Chi-squared test

# %%
library(MASS)       # load the MASS package 
tbl = table(states.data$csat, sat.mod$residuals) 
chisq.test(tbl)
# Out:
# Warning message in chisq.test(tbl):
# "Chi-squared approximation may be incorrect"
# 	Pearson's Chi-squared test
#
# data:  tbl
# X-squared = 2244, df = 2200, p-value = 0.2518

# %%
#plot(sat.mod)

# %% [markdown]
# #### Independent and linear relationships Test in Graph

# %%
par(mar = c(4, 4, 2, 2), mfrow = c(1, 2)) #optional
plot(sat.mod, which = c(1, 2)) # "which" argument optional
# Out:
# Plot with title ""

# %%
## Generate two data sets
## First Normal, second from a t-distribution
#words1 = rnorm(100)

## Have a look at the densities
#plot(density(words1))

## Perform the test
#shapiro.test(words1)
#qqnorm(words1)

# %% [markdown]
# ## Test for assumptions with multiple independent variables

# %%
library(car)
fit <- lm(mpg~disp+hp+wt+drat, data=mtcars)

# %% [markdown]
# ### Evaluate Nonlinearity

# %%
# component + residual plot 
crPlots(fit)
# Ceres plots 
ceresPlots(fit)
# Out:
# plot without title
# Plot with title ""

# %% [markdown]
# ### Evaluate Autocorrelation

# %%
durbinWatsonTest(fit)
# Out:
#  lag Autocorrelation D-W Statistic p-value
#    1        0.100862      1.735915    0.24
#  Alternative hypothesis: rho != 0

# %% [markdown]
# ### Evaluate Stationary

# %%
library(tseries)
set.seed(1)
x <- rnorm(50, 0, 3)
adf.test(x, k = 10)
# Out:
# 	Augmented Dickey-Fuller Test
#
# data:  x
# Dickey-Fuller = -1.6757, Lag order = 10, p-value = 0.7044
# alternative hypothesis: stationary
